# %% [markdown]
# ## Criação de Pacotes de Processamento de Imagens em Python
#
# ### Cientista de Dados Flayson Santos

# %% [markdown]
# EN: Loading installed package dependencies " pip install image-processing-img "
#
# PT: Carregamento das dependencias instaladas do pacote " pip install image-processing-img "

# %%
from image_processing_img.utils import io, plot
from image_processing_img.processing import combination, transfomation

# %% [markdown]
# EN:Reading and loading images with the function "io.read_image"
#
# PT: Leitura e carregamento das imagens com a função "io.read_image"

# %%
image1 = io.read_image('C:/Users/flays/Documents/Projeto Python/Pacotes de Processamento de Imagens/Imagens teste/3.jpg')
image2 = io.read_image('C:/Users/flays/Documents/Projeto Python/Pacotes de Processamento de Imagens/Imagens teste/1.jpg')

# %% [markdown]
# EN: plot image with the function "plot.plot_image"
# PT: Apresentando as imagens com a função "plot.plot_image"

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %% [markdown]
# EN: Creating and saving the combination of two images using the command "combination.transfer_histogram"
#
# PT: Criando e salvando a combinação das duas imagens por meio do comando "combination.transfer_histogram"

# %%
result = combination.transfer_histogram(image1, image2)

# %% [markdown]
# EN: Generating the third image called Result with a combination of two distinct images using the command "plot.plot_result"
#
# PT:

# %%
plot.plot_result(image1, image2, result)
